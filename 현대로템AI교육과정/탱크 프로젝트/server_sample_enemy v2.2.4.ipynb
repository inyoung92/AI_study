# %%
# !pip install flask torch ultralytics

# %%
from flask import Flask, request, jsonify
import os

app = Flask(__name__)

combined_commands = [
    {
        "moveWS": {"command": "W", "weight": 1.0},
    },
    {
        "moveWS": {"command": "W", "weight": 1.0},
    },
    {
        "moveWS": {"command": "W", "weight": 1.0},
    },
    {
        "moveWS": {"command": "W", "weight": 0.6},
    },
    {
        "moveWS": {"command": "W", "weight": 0.5},
        "moveAD": {"command": "", "weight": 0.0},
        "turretQE": {"command": "E", "weight": 0.4},
        "turretRF": {"command": "R", "weight": 0.6},
        "fire": False
    },
    {
        "moveWS": {"command": "W", "weight": 0.3},
        "moveAD": {"command": "D", "weight": 0.3},
        "fire": False
    },
    {
        "moveWS": {"command": "W", "weight": 0.3},
        "moveAD": {"command": "D", "weight": 0.3},
        "fire": False
    },
    {
        "moveWS": {"command": "W", "weight": 0.3},
        "moveAD": {"command": "D", "weight": 0.3},
        "fire": False
    },
]

@app.route('/get_action', methods=['POST'])
def get_action():
    data = request.get_json(force=True)

    position = data.get("position", {})
    turret = data.get("turret", {})

    pos_x = position.get("x", 0)
    pos_y = position.get("y", 0)
    pos_z = position.get("z", 0)

    turret_x = turret.get("x", 0)
    turret_y = turret.get("y", 0)

    print(f"📨 Position received: x={pos_x}, y={pos_y}, z={pos_z}")
    print(f"🎯 Turret received: x={turret_x}, y={turret_y}")

    if combined_commands:
        command = combined_commands.pop(0)
    else:
        command = {
            "moveWS": {"command": "STOP", "weight": 1.0},
            "moveAD": {"command": "", "weight": 0.0},
            "turretQE": {"command": "", "weight": 0.0},
            "turretRF": {"command": "", "weight": 0.0},
            "fire": False
        }

    print("🔁 Sent Combined Action:", command)
    return jsonify(command)

@app.route('/update_bullet', methods=['POST'])
def update_bullet():
    data = request.get_json()
    if not data:
        return jsonify({"status": "ERROR", "message": "Invalid request data"}), 400

    print(f"💥 Bullet Impact at X={data.get('x')}, Y={data.get('y')}, Z={data.get('z')}, Target={data.get('hit')}")
    return jsonify({"status": "OK", "message": "Bullet impact data received"})
    
if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5100)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5100
#  * Running on http://192.168.11.212:5100
# Press CTRL+C to quit
# 127.0.0.1 - - [26/May/2025 16:15:29] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=0.5, y=8.6, z=230.8
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 📨 Position received: x=0.52, y=8.6, z=230.82
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 127.0.0.1 - - [26/May/2025 16:15:29] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:29] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:30] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=0.58, y=8.6, z=230.87
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 📨 Position received: x=0.69, y=8.6, z=230.97
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 127.0.0.1 - - [26/May/2025 16:15:30] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:30] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=0.83, y=8.6, z=231.09
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 📨 Position received: x=0.99, y=8.6, z=231.23
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 127.0.0.1 - - [26/May/2025 16:15:30] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:30] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=1.25, y=8.6, z=231.46
# 🎯 Turret received: x=48.87, y=-0.01
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 📨 Position received: x=1.52, y=8.6, z=231.69
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 127.0.0.1 - - [26/May/2025 16:15:30] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=1.86, y=8.6, z=231.98
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 📨 Position received: x=2.25, y=8.6, z=232.33
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 127.0.0.1 - - [26/May/2025 16:15:30] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:31] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:31] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=2.73, y=8.6, z=232.75
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 📨 Position received: x=3.09, y=8.6, z=233.07
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 127.0.0.1 - - [26/May/2025 16:15:31] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=3.64, y=8.6, z=233.54
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 1.0}}
# 📨 Position received: x=4.23, y=8.6, z=234.06
# 🎯 Turret received: x=48.87, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.6}}
# 127.0.0.1 - - [26/May/2025 16:15:31] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:31] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:31] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=4.72, y=8.6, z=234.49
# 🎯 Turret received: x=48.88, y=0.0
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.5}, 'moveAD': {'command': '', 'weight': 0.0}, 'turretQE': {'command': 'E', 'weight': 0.4}, 'turretRF': {'command': 'R', 'weight': 0.6}, 'fire': False}
# 📨 Position received: x=5.4, y=8.6, z=235.08
# 🎯 Turret received: x=51.6, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:32] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:32] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=6.12, y=8.6, z=235.69
# 🎯 Turret received: x=53.21, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=6.79, y=8.6, z=236.23
# 🎯 Turret received: x=55.08, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:32] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=7.55, y=8.6, z=236.8
# 🎯 Turret received: x=57.09, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=8.32, y=8.6, z=237.34
# 🎯 Turret received: x=59.05, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:32] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:32] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:32] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=9.34, y=8.6, z=237.99
# 🎯 Turret received: x=61.55, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=10.2, y=8.6, z=238.5
# 🎯 Turret received: x=63.6, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:33] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:33] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=11.21, y=8.6, z=239.04
# 🎯 Turret received: x=65.95, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=12.08, y=8.6, z=239.46
# 🎯 Turret received: x=67.95, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:33] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:33] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=12.82, y=8.6, z=239.79
# 🎯 Turret received: x=69.61, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=13.63, y=8.6, z=240.13
# 🎯 Turret received: x=71.41, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:33] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:33] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=14.56, y=8.6, z=240.47
# 🎯 Turret received: x=73.45, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=15.44, y=8.6, z=240.77
# 🎯 Turret received: x=75.36, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:34] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:34] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=16.22, y=8.6, z=241.01
# 🎯 Turret received: x=77.05, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=17.17, y=8.59, z=241.26
# 🎯 Turret received: x=79.08, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:34] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:34] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=18.38, y=8.59, z=241.53
# 🎯 Turret received: x=81.62, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=19.11, y=8.59, z=241.66
# 🎯 Turret received: x=83.14, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': True}
# 127.0.0.1 - - [26/May/2025 16:15:34] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=19.96, y=8.59, z=241.8
# 🎯 Turret received: x=84.91, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=21.02, y=8.6, z=241.93
# 🎯 Turret received: x=87.12, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:34] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:35] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:35] "POST /update_bullet HTTP/1.1" 200 -
# 📨 Position received: x=22.23, y=8.6, z=242.02
# 🎯 Turret received: x=89.62, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 💥 Bullet Impact at X=63.28497, Y=7.874201, Z=246.5193, Target=terrain
# 127.0.0.1 - - [26/May/2025 16:15:35] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:35] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=23.37, y=8.59, z=242.06
# 🎯 Turret received: x=91.96, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=24.4, y=8.6, z=242.06
# 🎯 Turret received: x=94.07, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:35] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:35] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=25.4, y=8.6, z=242.03
# 🎯 Turret received: x=96.14, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=26.56, y=8.6, z=241.94
# 🎯 Turret received: x=98.52, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:36] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=27.54, y=8.6, z=241.82
# 🎯 Turret received: x=100.56, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:36] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:36] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=28.67, y=8.6, z=241.65
# 🎯 Turret received: x=102.91, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=30.21, y=8.6, z=241.33
# 🎯 Turret received: x=106.16, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:36] "POST /get_action HTTP/1.1" 200 -
# 127.0.0.1 - - [26/May/2025 16:15:36] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=31.16, y=8.6, z=241.09
# 🎯 Turret received: x=108.17, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 📨 Position received: x=31.93, y=8.6, z=240.87
# 🎯 Turret received: x=109.82, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
# 127.0.0.1 - - [26/May/2025 16:15:36] "POST /get_action HTTP/1.1" 200 -
# 📨 Position received: x=32.7, y=8.6, z=240.62
# 🎯 Turret received: x=111.47, y=0.51
# 🔁 Sent Combined Action: {'moveWS': {'command': 'W', 'weight': 0.3}, 'moveAD': {'command': 'D', 'weight': 0.3}, 'fire': False}
