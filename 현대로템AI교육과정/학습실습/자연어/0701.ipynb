# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard  #분석용 보드

from sklearn import linear_model
from sklearn.metrics import accuracy_score

# 파이토치 사용시 불러올 모듈
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

# Tensorflow Keras 구현에 비해 PyTorch구현은 low leval구현의 분위기
# 텐소플로우보다 파이토치가 구현하는게 좀 더 디테일하게 구현이 가능하다. 그리고 빠르다
# PyTorch Lightning -> 케라스 분위기를 냄. 속도는 좀 내리지만 편리성이 높은 모듈이다. Lightning으로 23년에 이름이 변경됨
# Out:
# 2025-07-01 11:14:12.306610: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-01 11:14:12.429253: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-01 11:14:12.488619: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-01 11:14:12.489550: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import tensorflow as tf

print(tf.__version__)  # 2.16.1

# 물리적인 GPU 목록 출력
print("Available GPU devices:")
print(tf.config.list_physical_devices('GPU'))

# Available GPU devices:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Out:
# 2.16.2
# Available GPU devices:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2025-07-01 11:14:16.336875: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-01 11:14:16.340662: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-01 11:14:16.340707: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# PyTorch version: 2.2.2+cu121
# CUDA available: True
# CUDA version: 12.1
# Out:
# PyTorch version: 2.2.2+cu121
# CUDA available: True
# CUDA version: 12.1

# %%
#Training Data Set
x_data = np.array([[0,0],
                  [0,1],
                  [1,0],
                 [1,1]],dtpye)

#And 연산
y_data = np.array([0,0,0,1])

# %%
#sklearn 구현
# Logistic Refression으로 구현
# 머신러닝 vs 딥러닝
# 머신러닝 기법
# -> Regression, KNN, SVM, Decision Tree, Randon Forestr, XGBoost, LightGBM

# %%
keras_model = Sequential()
keras_model.add(Flatten(input_shape=(2,))) 들어오는 데이터 한건(샘플의 한건의 쉐입)의 쉐입
keras_model.add(Dense(units=1,activation='sigmoid'))
keras_model.compile(optimizer=Adam(learning_rate=1e-3),loss='binary_crossentropy', metrics=['accuracy'])

# %%
keras_model.fit(x_data,
               y_data,
               epochs=500,
               verbose=0,
               callbacks=[tb_callback])

keras_y_pred = keras_model.predict(x_data)
#이렇게 하면 확률값이 나와요 0,0->확률, 0,1->확률, ....
keras_y_pred_lass = (keras_y_pred >= 0.5).astype(int)
#keras_y_pred -> [0.7,0.5,0.3,0.9] >=0.5
# => [True True False True].astype(int)
# -> [1 1 0 1]
print(accuracy_score(y_data,keras_y_pred_lass))

# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 +np.exp(-x))
    
z1 = 0.47
z2 = 0.33
print(sigmoid(z1), sigmoid(z2))
# Out:
# 0.6153837563911821 0.5817593768418363
